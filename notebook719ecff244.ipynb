# %%
import numpy as np
import cv2

import PIL.Image as Image
#import os

import matplotlib.pylab as plt

# import tensorflow as tf
#import tensorflow_hub as tensorflow_hub

from tensorflow import keras
#from tensorflow.keras import layers
#from tensorflow.keras.models import Sequential

import pathlib
import dlib

from sklearn.metrics import euclidean_distances
from tensorflow.keras.optimizers import Adam

# %%
IMG_HEIGHT=224 
IMG_WIDTH = 224
batch_size=32

# %%
apple_scab_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/'
apple_black_rot_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Black_rot'
apple_rust_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Cedar_apple_rust/'
apple_healthy_dir = '/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___healthy/'

# %%
apple_scab_dir = pathlib.Path(apple_scab_dir)
print(apple_scab_dir)
apple_black_rot_dir = pathlib.Path(apple_black_rot_dir)
print(apple_black_rot_dir)
apple_rust_dir = pathlib.Path(apple_rust_dir)
print(apple_rust_dir)
apple_healthy_dir = pathlib.Path(apple_healthy_dir)
print(apple_healthy_dir)
# Out:
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Black_rot
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Cedar_apple_rust
# /kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___healthy

# %%
list(apple_scab_dir.glob('*'))[:5]
# Out:
# [PosixPath('/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/c4e2b47d-d3c9-418e-9e60-78cead67c5d7___FREC_Scab 2928_new30degFlipLR.JPG'),
#  PosixPath('/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/9555b45b-0080-4d26-8b54-a343b9bf0ffc___FREC_Scab 3313_90deg.JPG'),
#  PosixPath('/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/5a178d63-372d-48c4-adb8-d616130ba3f0___FREC_Scab 3104.JPG'),
#  PosixPath('/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/0a6812de-7416-4ffe-aba9-307599a02c84___FREC_Scab 2973_270deg.JPG'),
#  PosixPath('/kaggle/input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train/Apple___Apple_scab/6b5e1187-9b7b-4b4c-912f-b2175619f35f___FREC_Scab 3121_90deg.JPG')]

# %%
image_count = len(list(apple_scab_dir.glob('*')))
image_count
# Out:
# 2016

# %%
healthy = list(apple_healthy_dir.glob("*"))
Image.open(str(healthy[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256>

# %%
image_dict = {
    'scab': list(apple_scab_dir.glob('*')),
    'black_rot' : list(apple_black_rot_dir.glob('*')),
    'rust': list(apple_rust_dir.glob('*')),
    'healthy' : list(apple_healthy_dir.glob('*')),
}

# %%
labels_dict = {
    'scab': 0,
    'black_rot' : 1,
    'rust': 2,
    'healthy' : 3,
}

labels_class = ['scab','black_rot','rust','healthy']

# %%
X = []
y = []

for label, images in image_dict.items():
  for image in images:
    img = cv2.imread(str(image))
#     gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    resized_img = cv2.resize(img, (IMG_HEIGHT, IMG_WIDTH))

    X.append(resized_img)
    y.append(labels_dict[label])

# %%
X = np.array(X)
y = np.array(y)

# %%
X.shape
#y.shape
# Out:
# (7771, 224, 224, 3)

# %%
X_reshaped = X.reshape(3,-1)
X_reshaped
# Out:
# array([[  0,   0,   0, ..., 107,  58,  44],
#        [109,  61,  21, ...,  91,  49, 116],
#        [ 80,  47, 112, ..., 125, 127, 145]], dtype=uint8)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
import tensorflow_hub as hub
feature_extractor_model = "https://tfhub.dev/google/imagenet/mobilenet_v2_075_224/classification/5"

pretrained_model_without_top_layer = hub.KerasLayer(
    feature_extractor_model, input_shape=(224, 224, 3), trainable=False)
# Out:
# 2023-01-27 19:56:51.803511: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:51.834679: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:51.835816: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:51.838993: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-27 19:56:51.839481: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:51.840468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:51.841412: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:53.858079: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:53.858976: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:53.859660: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-27 19:56:53.860246: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from keras.models import Sequential
from keras.layers import Activation, Dense
model = Sequential([
#  data_augmentation,
  pretrained_model_without_top_layer,
  Dense(4,activation='softmax')
])

# %%
model.compile(optimizer = 'adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1001)              2664345
# _________________________________________________________________
# dense (Dense)                (None, 4)                 4008
# =================================================================
# Total params: 2,668,353
# Trainable params: 4,008
# Non-trainable params: 2,664,345
# _________________________________________________________________
# None

# %%
epochs=100

# %%
history = model.fit(X_train,y_train,epochs = 100 , validation_data = (X_test, y_test))
# Out:
# 2023-01-27 19:56:56.399486: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 877277184 exceeds 10% of free system memory.
# 2023-01-27 19:56:57.377884: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 877277184 exceeds 10% of free system memory.
# 2023-01-27 19:56:58.091580: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2023-01-27 19:57:02.007757: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 183/183 [==============================] - 16s 37ms/step - loss: 0.7308 - accuracy: 0.7147 - val_loss: 0.5193 - val_accuracy: 0.8075
# Epoch 2/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.4572 - accuracy: 0.8308 - val_loss: 0.4151 - val_accuracy: 0.8456
# Epoch 3/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.4021 - accuracy: 0.8505 - val_loss: 0.3870 - val_accuracy: 0.8564
# Epoch 4/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.3555 - accuracy: 0.8723 - val_loss: 0.3485 - val_accuracy: 0.8734
# Epoch 5/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.3388 - accuracy: 0.8708 - val_loss: 0.3412 - val_accuracy: 0.8718
# Epoch 6/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.3155 - accuracy: 0.8878 - val_loss: 0.3290 - val_accuracy: 0.8744
# Epoch 7/100
# 183/183 [==============================] - 6s 31ms/step - loss: 0.3152 - accuracy: 0.8854 - val_loss: 0.3619 - val_accuracy: 0.8713
# Epoch 8/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.3105 - accuracy: 0.8845 - val_loss: 0.3032 - val_accuracy: 0.8837
# Epoch 9/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2954 - accuracy: 0.8898 - val_loss: 0.2939 - val_accuracy: 0.8971
# Epoch 10/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2880 - accuracy: 0.8950 - val_loss: 0.2937 - val_accuracy: 0.8971
# Epoch 11/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.2753 - accuracy: 0.8967 - val_loss: 0.3140 - val_accuracy: 0.8847
# Epoch 12/100
# 183/183 [==============================] - 6s 30ms/step - loss: 0.2753 - accuracy: 0.9024 - val_loss: 0.2816 - val_accuracy: 0.9043
# Epoch 13/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2668 - accuracy: 0.9024 - val_loss: 0.2775 - val_accuracy: 0.8996
# Epoch 14/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2555 - accuracy: 0.9065 - val_loss: 0.2671 - val_accuracy: 0.9043
# Epoch 15/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2543 - accuracy: 0.9085 - val_loss: 0.2732 - val_accuracy: 0.9007
# Epoch 16/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2578 - accuracy: 0.9060 - val_loss: 0.2705 - val_accuracy: 0.9048
# Epoch 17/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2583 - accuracy: 0.9075 - val_loss: 0.2615 - val_accuracy: 0.9074
# Epoch 18/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2404 - accuracy: 0.9084 - val_loss: 0.2677 - val_accuracy: 0.9038
# Epoch 19/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2427 - accuracy: 0.9111 - val_loss: 0.2956 - val_accuracy: 0.8899
# Epoch 20/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2413 - accuracy: 0.9132 - val_loss: 0.2744 - val_accuracy: 0.8981
# Epoch 21/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.2314 - accuracy: 0.9163 - val_loss: 0.2988 - val_accuracy: 0.8919
# Epoch 22/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2366 - accuracy: 0.9149 - val_loss: 0.2646 - val_accuracy: 0.9043
# Epoch 23/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2329 - accuracy: 0.9133 - val_loss: 0.2841 - val_accuracy: 0.8863
# Epoch 24/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2240 - accuracy: 0.9183 - val_loss: 0.2612 - val_accuracy: 0.9038
# Epoch 25/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2411 - accuracy: 0.9094 - val_loss: 0.2824 - val_accuracy: 0.8945
# Epoch 26/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2264 - accuracy: 0.9166 - val_loss: 0.2696 - val_accuracy: 0.8996
# Epoch 27/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.2113 - accuracy: 0.9279 - val_loss: 0.2559 - val_accuracy: 0.9022
# Epoch 28/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2187 - accuracy: 0.9183 - val_loss: 0.2684 - val_accuracy: 0.8991
# Epoch 29/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2140 - accuracy: 0.9218 - val_loss: 0.3097 - val_accuracy: 0.8929
# Epoch 30/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2178 - accuracy: 0.9221 - val_loss: 0.2617 - val_accuracy: 0.9084
# Epoch 31/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2112 - accuracy: 0.9170 - val_loss: 0.2632 - val_accuracy: 0.8971
# Epoch 32/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2117 - accuracy: 0.9204 - val_loss: 0.2698 - val_accuracy: 0.8971
# Epoch 33/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2106 - accuracy: 0.9221 - val_loss: 0.2634 - val_accuracy: 0.9068
# Epoch 34/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2013 - accuracy: 0.9260 - val_loss: 0.2687 - val_accuracy: 0.9007
# Epoch 35/100
# 183/183 [==============================] - 6s 31ms/step - loss: 0.2112 - accuracy: 0.9245 - val_loss: 0.2465 - val_accuracy: 0.9084
# Epoch 36/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2041 - accuracy: 0.9242 - val_loss: 0.2641 - val_accuracy: 0.9017
# Epoch 37/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2157 - accuracy: 0.9202 - val_loss: 0.2597 - val_accuracy: 0.9022
# Epoch 38/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2063 - accuracy: 0.9254 - val_loss: 0.3007 - val_accuracy: 0.8857
# Epoch 39/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.1967 - accuracy: 0.9271 - val_loss: 0.2486 - val_accuracy: 0.9089
# Epoch 40/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.2020 - accuracy: 0.9269 - val_loss: 0.2499 - val_accuracy: 0.9084
# Epoch 41/100
# 183/183 [==============================] - 7s 37ms/step - loss: 0.1963 - accuracy: 0.9276 - val_loss: 0.2556 - val_accuracy: 0.9063
# Epoch 42/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1987 - accuracy: 0.9303 - val_loss: 0.2589 - val_accuracy: 0.9068
# Epoch 43/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1982 - accuracy: 0.9276 - val_loss: 0.2547 - val_accuracy: 0.9027
# Epoch 44/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1886 - accuracy: 0.9348 - val_loss: 0.2572 - val_accuracy: 0.9094
# Epoch 45/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1950 - accuracy: 0.9309 - val_loss: 0.2556 - val_accuracy: 0.9063
# Epoch 46/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1895 - accuracy: 0.9315 - val_loss: 0.2502 - val_accuracy: 0.9099
# Epoch 47/100
# 183/183 [==============================] - 6s 31ms/step - loss: 0.1894 - accuracy: 0.9290 - val_loss: 0.2653 - val_accuracy: 0.9007
# Epoch 48/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.2017 - accuracy: 0.9200 - val_loss: 0.3011 - val_accuracy: 0.8976
# Epoch 49/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1880 - accuracy: 0.9333 - val_loss: 0.3016 - val_accuracy: 0.8950
# Epoch 50/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1856 - accuracy: 0.9303 - val_loss: 0.2559 - val_accuracy: 0.9079
# Epoch 51/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1906 - accuracy: 0.9293 - val_loss: 0.2949 - val_accuracy: 0.8914
# Epoch 52/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1814 - accuracy: 0.9336 - val_loss: 0.2702 - val_accuracy: 0.9022
# Epoch 53/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1901 - accuracy: 0.9305 - val_loss: 0.2957 - val_accuracy: 0.8909
# Epoch 54/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1845 - accuracy: 0.9338 - val_loss: 0.3009 - val_accuracy: 0.8924
# Epoch 55/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1798 - accuracy: 0.9336 - val_loss: 0.2576 - val_accuracy: 0.9110
# Epoch 56/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1781 - accuracy: 0.9326 - val_loss: 0.2513 - val_accuracy: 0.9104
# Epoch 57/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1824 - accuracy: 0.9312 - val_loss: 0.2499 - val_accuracy: 0.9094
# Epoch 58/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1847 - accuracy: 0.9321 - val_loss: 0.2668 - val_accuracy: 0.8950
# Epoch 59/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1742 - accuracy: 0.9358 - val_loss: 0.2614 - val_accuracy: 0.9043
# Epoch 60/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1825 - accuracy: 0.9345 - val_loss: 0.2620 - val_accuracy: 0.8986
# Epoch 61/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.1785 - accuracy: 0.9319 - val_loss: 0.2511 - val_accuracy: 0.9104
# Epoch 62/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1749 - accuracy: 0.9333 - val_loss: 0.2738 - val_accuracy: 0.9032
# Epoch 63/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1815 - accuracy: 0.9314 - val_loss: 0.2806 - val_accuracy: 0.9048
# Epoch 64/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1722 - accuracy: 0.9346 - val_loss: 0.2479 - val_accuracy: 0.9084
# Epoch 65/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1700 - accuracy: 0.9381 - val_loss: 0.2788 - val_accuracy: 0.9007
# Epoch 66/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1789 - accuracy: 0.9350 - val_loss: 0.2736 - val_accuracy: 0.9089
# Epoch 67/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.1762 - accuracy: 0.9329 - val_loss: 0.3085 - val_accuracy: 0.8940
# Epoch 68/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1731 - accuracy: 0.9346 - val_loss: 0.2580 - val_accuracy: 0.9053
# Epoch 69/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1688 - accuracy: 0.9386 - val_loss: 0.3133 - val_accuracy: 0.8919
# Epoch 70/100
# 183/183 [==============================] - 6s 30ms/step - loss: 0.1765 - accuracy: 0.9348 - val_loss: 0.2834 - val_accuracy: 0.9022
# Epoch 71/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1703 - accuracy: 0.9379 - val_loss: 0.2864 - val_accuracy: 0.8996
# Epoch 72/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1677 - accuracy: 0.9384 - val_loss: 0.2583 - val_accuracy: 0.9063
# Epoch 73/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1656 - accuracy: 0.9403 - val_loss: 0.2914 - val_accuracy: 0.8996
# Epoch 74/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1661 - accuracy: 0.9396 - val_loss: 0.2544 - val_accuracy: 0.9084
# Epoch 75/100
# 183/183 [==============================] - 6s 30ms/step - loss: 0.1717 - accuracy: 0.9367 - val_loss: 0.3069 - val_accuracy: 0.8996
# Epoch 76/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1661 - accuracy: 0.9362 - val_loss: 0.2686 - val_accuracy: 0.9027
# Epoch 77/100
# 183/183 [==============================] - 7s 36ms/step - loss: 0.1607 - accuracy: 0.9422 - val_loss: 0.2584 - val_accuracy: 0.9058
# Epoch 78/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1616 - accuracy: 0.9393 - val_loss: 0.2542 - val_accuracy: 0.9094
# Epoch 79/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1686 - accuracy: 0.9377 - val_loss: 0.2611 - val_accuracy: 0.9007
# Epoch 80/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1731 - accuracy: 0.9350 - val_loss: 0.2945 - val_accuracy: 0.8935
# Epoch 81/100
# 183/183 [==============================] - 6s 32ms/step - loss: 0.1618 - accuracy: 0.9415 - val_loss: 0.3000 - val_accuracy: 0.8976
# Epoch 82/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1735 - accuracy: 0.9329 - val_loss: 0.2696 - val_accuracy: 0.9032
# Epoch 83/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1631 - accuracy: 0.9405 - val_loss: 0.2555 - val_accuracy: 0.9135
# Epoch 84/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1683 - accuracy: 0.9367 - val_loss: 0.2824 - val_accuracy: 0.9053
# Epoch 85/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1537 - accuracy: 0.9447 - val_loss: 0.2562 - val_accuracy: 0.9094
# Epoch 86/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1554 - accuracy: 0.9406 - val_loss: 0.2502 - val_accuracy: 0.9084
# Epoch 87/100
# 183/183 [==============================] - 6s 31ms/step - loss: 0.1618 - accuracy: 0.9411 - val_loss: 0.2580 - val_accuracy: 0.9053
# Epoch 88/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1562 - accuracy: 0.9413 - val_loss: 0.2858 - val_accuracy: 0.8986
# Epoch 89/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1609 - accuracy: 0.9403 - val_loss: 0.2820 - val_accuracy: 0.8981
# Epoch 90/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1559 - accuracy: 0.9413 - val_loss: 0.3097 - val_accuracy: 0.8868
# Epoch 91/100
# 183/183 [==============================] - 5s 30ms/step - loss: 0.1586 - accuracy: 0.9405 - val_loss: 0.2661 - val_accuracy: 0.9074
# Epoch 92/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1552 - accuracy: 0.9420 - val_loss: 0.2872 - val_accuracy: 0.9027
# Epoch 93/100
# 183/183 [==============================] - 6s 31ms/step - loss: 0.1565 - accuracy: 0.9429 - val_loss: 0.2715 - val_accuracy: 0.9115
# Epoch 94/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1550 - accuracy: 0.9398 - val_loss: 0.2614 - val_accuracy: 0.9058
# Epoch 95/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1506 - accuracy: 0.9446 - val_loss: 0.2834 - val_accuracy: 0.9079
# Epoch 96/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1665 - accuracy: 0.9372 - val_loss: 0.3358 - val_accuracy: 0.8837
# Epoch 97/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1580 - accuracy: 0.9429 - val_loss: 0.2599 - val_accuracy: 0.9125
# Epoch 98/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1552 - accuracy: 0.9415 - val_loss: 0.2590 - val_accuracy: 0.9053
# Epoch 99/100
# 183/183 [==============================] - 7s 37ms/step - loss: 0.1598 - accuracy: 0.9387 - val_loss: 0.2726 - val_accuracy: 0.9043
# Epoch 100/100
# 183/183 [==============================] - 5s 29ms/step - loss: 0.1487 - accuracy: 0.9441 - val_loss: 0.2624 - val_accuracy: 0.9089

# %%
model.save('crop_disease_model.h5')

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(100)

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
